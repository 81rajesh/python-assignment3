# %%
#question 1.1

def myreduce(x,new_list):
    return a
## we have to define a function which make addition of two numbers in list
## we have to specify the values of a and b
def x(a,b):
    return a+b
a=new_list[0]
for i in range(1,len(new_list)):
    b=new_list[i]
    a=a+b
print(myreduce(x,new_list))
# Out:
# 6

# %%
# question 1.2

def myfilter(a,list1):
    return c(a)
def c(a):
    list1=[1,2,3,'abc','xyz',24,56]
    l=[]
    for i in list1:
        if type(i)== str:
            l.append(i)
    print(l)
myfilter(a,list1)
# Out:
# ['abc', 'xyz']

# %% [markdown]
# Question 2

# %%
l=['x','y','z']
l1=[i * n for i in l for n in range(1,5)]

# %%
l1
# Out:
# ['x', 'xx', 'xxx', 'xxxx', 'y', 'yy', 'yyy', 'yyyy', 'z', 'zz', 'zzz', 'zzzz']

# %%
l2=[i * n for n in range(1,5) for i in l]

# %%
l2
# Out:
# ['x', 'y', 'z', 'xx', 'yy', 'zz', 'xxx', 'yyy', 'zzz', 'xxxx', 'yyyy', 'zzzz']

# %%
sl=[2,3,4]

# %%
l3=[[i + n] for i in sl for n in range(0,3)]

# %%
l3
# Out:
# [[2], [3], [4], [3], [4], [5], [4], [5], [6]]

# %%
nl=[2,3,4,5]

# %%
l4=[[i + n for i in nl] for n in range(0,4)]

# %%
l4
# Out:
# [[2, 3, 4, 5], [3, 4, 5, 6], [4, 5, 6, 7], [5, 6, 7, 8]]

# %%
cl=[1,2,3]

# %%
l5=[(b,a) for a in cl for b in cl]

# %%
l5
# Out:
# [(1, 1), (2, 1), (3, 1), (1, 2), (2, 2), (3, 2), (1, 3), (2, 3), (3, 3)]
